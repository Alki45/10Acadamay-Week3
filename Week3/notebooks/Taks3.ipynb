# %%
import pandas as pd
from scipy.stats import chi2_contingency, ttest_ind

# %%
# Load your dataset
data = pd.read_csv('A:/10x/10Acadamay-Week3/Data_Ver/Insurance_Data.csv')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22748\700483299.py:2: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('A:/10x/10Acadamay-Week3/Data_Ver/Insurance_Data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  UnderwrittenCoverID  PolicyID     TransactionMonth  \
# 0           0               145249     12827  2015-03-01 00:00:00
# 1           1               145249     12827  2015-05-01 00:00:00
# 2           2               145249     12827  2015-07-01 00:00:00
# 3           3               145255     12827  2015-05-01 00:00:00
# 4           4               145255     12827  2015-07-01 00:00:00
#
#    IsVATRegistered Citizenship          LegalType Title Language  \
# 0             True              Close Corporation    Mr  English
# 1             True              Close Corporation    Mr  English
# 2             True              Close Corporation    Mr  English
# 3             True              Close Corporation    Mr  English
# 4             True              Close Corporation    Mr  English
#
#                   Bank  ...                    ExcessSelected CoverCategory  \
# 0  First National Bank  ...             Mobility - Windscreen    Windscreen
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
# Key performance indicators (KPIs)
kpis = {
    'TotalPremium': 'Total Premium',
    'TotalClaims': 'Total Claims'
}

# %%
data.CoverType.value_counts()
# Out:
# CoverType
# Own Damage                                             104183
# Passenger Liability                                    104158
# Windscreen                                             103763
# Third Party                                            102825
# Keys and Alarms                                        102428
# Signage and Vehicle Wraps                              102416
# Emergency Charges                                      102416
# Cleaning and Removal of Accident Debris                102414
# Income Protector                                        64813
# Basic Excess Waiver                                     57769
# Accidental Death                                        27321
# Credit Protection                                       18070
# Roadside Assistance                                      3834
# Deposit Cover                                            1299
# Asset Value Preserver                                     865
# ...

# %%
# Statistical Testing
# 1. Risk differences across provinces
provinces_control = control_group['Province'].value_counts()
provinces_test = test_group['Province'].value_counts()
province_contingency = pd.DataFrame({'Control': provinces_control, 'Test': provinces_test}).fillna(0)

chi2_stat, p_value_province, dof, expected = stats.chi2_contingency(province_contingency)
print(f"Chi-squared Statistic for Provinces: {chi2_stat}, P-value: {p_value_province}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 7
#       4 provinces_test = test_group['Province'].value_counts()
#       5 province_contingency = pd.DataFrame({'Control': provinces_control, 'Test': provinces_test}).fillna(0)
# ----> 7 chi2_stat, p_value_province, dof, expected = stats.chi2_contingency(province_contingency)
#       8 print(f"Chi-squared Statistic for Provinces: {chi2_stat}, P-value: {p_value_province}")
#
# File a:\10x\10Acadamay-Week3\.venv\lib\site-packages\scipy\stats\contingency.py:333, in chi2_contingency(observed, correction, lambda_)
#     331     raise ValueError("All values in `observed` must be nonnegative.")
#     332 if observed.size == 0:
# --> 333     raise ValueError("No data; `observed` has size 0.")
#     335 expected = expected_freq(observed)
#     336 if np.any(expected == 0):
# ...

# %%
# 2. Risk differences between zip codes
zipcodes_control = control_group['PostalCode'].value_counts()
zipcodes_test = test_group['PostalCode'].value_counts()
zipcode_contingency = pd.DataFrame({'Control': zipcodes_control, 'Test': zipcodes_test}).fillna(0)

# %%
# Convert Gender to numerical values
gender_mapping = {
    'Male': 1,
    'Female': 0,
    'Not specified': None  
}

# Apply mapping to the Gender column
data['Gender'] = data['Gender'].replace(gender_mapping)

# %%
data.Gender
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 1000093    1.0
# 1000094    1.0
# 1000095    1.0
# 1000096    1.0
# 1000097    1.0
# Name: Gender, Length: 1000098, dtype: float64

# %%
# Convert Gender to numerical values
AlarmImmobiliser_mapping = {
    'Yes': 1,
    'No': 0,
}

# Apply mapping to the Gender column
data['AlarmImmobiliser'] = data['AlarmImmobiliser'].replace(gender_mapping)

# %%
data.AlarmImmobiliser
# Out:
# 0          Yes
# 1          Yes
# 2          Yes
# 3          Yes
# 4          Yes
#           ...
# 1000093    Yes
# 1000094    Yes
# 1000095    Yes
# 1000096    Yes
# 1000097    Yes
# Name: AlarmImmobiliser, Length: 1000098, dtype: object

# %%
# Data Segmentation based on AlarmImmobiliser values
group_a = data[data['AlarmImmobiliser'] == 'No']  # Control group
group_b = data[data['AlarmImmobiliser'] == 'Yes']  # Test group

# %%
group_a
# Out:
#         Unnamed: 0  UnderwrittenCoverID  PolicyID     TransactionMonth  \
# 216226      216226                52511      4284  2014-08-01 00:00:00
# 216227      216227                52511      4284  2014-10-01 00:00:00
# 216228      216228                52511      4284  2014-12-01 00:00:00
# 216229      216229                52511      4284  2015-03-01 00:00:00
# 216230      216230                52511      4284  2015-05-01 00:00:00
# ...            ...                  ...       ...                  ...
# 489561      489561               260135     22031  2015-07-01 00:00:00
# 584856      584856               260140     22031  2015-07-01 00:00:00
# 584857      584857               260138     22031  2015-06-01 00:00:00
# 584858      584858               260138     22031  2015-08-01 00:00:00
# 584859      584859               260139     22031  2015-07-01 00:00:00
#
#         IsVATRegistered Citizenship   LegalType Title Language  \
# ...

# %%
# Check the sizes of the groups
print("Group A size:", group_a.shape[0])
print("Group B size:", group_b.shape[0])
# Out:
# Group A size: 237
# Group B size: 999861

# %%
unique_values = data['AlarmImmobiliser'].unique()

# %%
unique_values
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['AlarmImmobiliser'].value_counts()
# Out:
# AlarmImmobiliser
# Yes    999861
# No        237
# Name: count, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 2
#       1 # Chi-squared test for Gender distribution
# ----> 2 chi2_stat, p_value_gender = stats.chi2_contingency([gender_counts_a, gender_counts_b])[:2]
#       3 print(f"P-value for gender distribution: {p_value_gender}")
#       5 # Statistical Testing
#       6 # Hypothesis: Risk differences between groups based on 'RiskScore'
#
# File a:\10x\10Acadamay-Week3\.venv\lib\site-packages\scipy\stats\contingency.py:329, in chi2_contingency(observed, correction, lambda_)
#     144 def chi2_contingency(observed, correction=True, lambda_=None):
#     145     """Chi-square test of independence of variables in a contingency table.
#     146
#     147     This function computes the chi-square statistic and p-value for the
#    (...)
#     327     0.64417725029295503
#     328     """
# ...

# %%
# Interpret Results
alpha = 0.05
if p_value_risk < alpha:
    print("Reject the null hypothesis: There is a significant risk difference between groups.")
else:
    print("Fail to reject the null hypothesis: No significant risk difference between groups.")
